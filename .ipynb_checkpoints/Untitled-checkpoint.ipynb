# %%
from flask import Flask
from flask_sqlalchemy import SQLAlchemy
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] ='sqlite:///' +  'data.sqlite'
app.config['SQLALCHEMY_COMMIT_ON_TEARDOWN'] = True
db = SQLAlchemy(app)
# Out:
# C:\Users\J\AppData\Local\Continuum\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
Upcoming = pd.read_sql_table('Upcoming', db.engine)

Upcoming.release_date = Upcoming.release_date.apply(lambda x: pd.to_datetime('2018/' + x[:-2].replace('月','/').replace('日','')))

Upcoming.sort_values('release_date', inplace=True)

# %%
db.engine.table_names()
# Out:
# ['LibSeat', 'NowPlaying', 'Upcoming', 'alembic_version', 'roles', 'users']

# %%
a = db.Query('LibSeat')

# %%
class Lib(db.Model):
    __tablename__ = 'LibSeat'
    id = db.Column(db.Integer, primary_key=True)
    index = db.Column(db.String(64))
    姓名 = db.relationship('User', backref='role', lazy='dynamic')
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-38-eeb535670f24> in <module>()
# ----> 1 class Lib(db.Model):
#       2     __tablename__ = 'LibSeat'
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\flask_sqlalchemy\model.py in __init__(cls, name, bases, d)
#      65             cls.__tablename__ = camel_to_snake_case(cls.__name__)
#      66
# ---> 67         super(NameMetaMixin, cls).__init__(name, bases, d)
#      68
#      69         # __table_cls__ has run at this point
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\flask_sqlalchemy\model.py in __init__(cls, name, bases, d)
#     119         )
#     120
# --> 121         super(BindMetaMixin, cls).__init__(name, bases, d)
#     122
#     123         if bind_key is not None and hasattr(cls, '__table__'):
#
# ...

# %%
calss

# %%
db.session.query('LibSeat').all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# OperationalError: no such column: LibSeat
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-37-0d4ec3ff73e4> in <module>()
# ...

# %%
Seat = pd.read_sql_table('LibSeat', db.engine)

# %%
Seat
# Out:
#       index         姓名    座位号     状态              选座时间
# 0         0         王俊  1A001  doing  2017-12-27 18:49
# 1         1         范迪  1A002  doing  2017-12-27 20:03
# 2         2        刘洪康  1A003  doing  2017-12-27 18:58
# 3         3        徐俊峰  1A004  doing  2017-12-27 18:04
# 4         4        莫松奇  1A006  doing  2017-12-27 17:51
# 5         5        李松泽  1A007  doing  2017-12-27 18:28
# 6         6         安麒  1A008  doing  2017-12-27 19:43
# 7         7        唐佳慧  1A009  doing  2017-12-27 18:47
# 8         8        卜冬青  1A010  doing  2017-12-27 18:19
# 9         9        陶雨祺  1A012  doing  2017-12-27 17:04
# 10       10        张志祥  1A013  doing  2017-12-27 08:15
# 11       11        滕沄楼  1A014  doing  2017-12-27 15:12
# 12       12         唐乐  1A015  doing  2017-12-27 15:12
# 13       13        伍慧玲  1A016  doing  2017-12-27 10:47
# 14       14         李菲  1A018  doing  2017-12-27 12:12
# 15       15        郑炫杉  1A019  doing  2017-12-27 19:27
# ...

# %%
pd.read_sql_query('select * from LibSeat where 姓名 = "{}"'.format('吴杰德'), db.engine).iloc[0]
# Out:
# index                1229
# 姓名                    吴杰德
# 座位号                 4C257
# 状态                  doing
# 选座时间     2017-12-27 15:10
# Name: 0, dtype: object

# %%
pd.read_sql_query('select * from LibSeat where 姓名 = "{}"'.format('吴杰德'), db.engine).iloc[0]
